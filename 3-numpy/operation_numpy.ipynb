# %% [markdown]
# ### Advance operation with bussiness exempale

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data structure : [restaurent_id,2021,2022,2023,2024]
sales_data =np.array([
    [1,150000,180000,220000,250000]  # birani
    [2,120000,140000,160000,190000]  #bites
    [3,200000,240000,245624,240000] #pizza  hub
    [4,180000,210000,240000,270000]  #burger point
    [5,160000,185000,205000,230000]  # hai point
])

# %% [markdown]
# ### print("=== zomato sales analysis")

# %%
print("\n sales data shape",sales_data.shape)
