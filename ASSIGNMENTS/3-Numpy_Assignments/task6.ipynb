# %%
import numpy as np

# %%
marks = np.array([78, 85, 90, 67, 88, 92, 76, 81, 95, 73])

# %%
# 1. Sort the array
sorted_marks = np.sort(marks)
print("Sorted Marks:", sorted_marks)
# Out:
# Sorted Marks: [67 73 76 78 81 85 88 90 92 95]

# %%
# 2. Percentiles
print("25th Percentile:", np.percentile(marks, 25))
print("50th Percentile (Median):", np.percentile(marks, 50))
print("75th Percentile:", np.percentile(marks, 75))
# Out:
# 25th Percentile: 76.5
# 50th Percentile (Median): 83.0
# 75th Percentile: 89.5

# %%
# 3. Count students above average
average = np.mean(marks)
count = np.sum(marks > average)

print("Average Marks:", average)
print("Students Above Average:", count)
# Out:
# Average Marks: 82.5
# Students Above Average: 5
