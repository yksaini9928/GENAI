# %%
import pandas as pd

students={"name":["Amit","Neha","Rahul","Sneha","Pooja"],"Markes":[78,85,90,66,72],"Subject":["Math","Math","Scince","Scince","Math",]}

# convert into data frame

student= pd.DataFrame(students)

student
# Out:
#     name  Markes Subject
# 0   Amit      78    Math
# 1   Neha      85    Math
# 2  Rahul      90  Scince
# 3  Sneha      66  Scince
# 4  Pooja      72    Math

# %%
# First 3 rows
print("\nFirst 3 Rows:")
print(student.head(3))
# Out:
# First 3 Rows:
#     name  Markes Subject
# 0   Amit      78    Math
# 1   Neha      85    Math
# 2  Rahul      90  Scince

# %%
# Last 2 rows
print("\nLast 2 Rows:")
print(student.tail(2))
# Out:
# Last 2 Rows:
#     name  Markes Subject
# 3  Sneha      66  Scince
# 4  Pooja      72    Math

# %%
# Shape
print("\nShape:")
print(student.shape)

# Column Names
print("\nColumn Names:")
print(student.columns)
# Out:
# Shape:
# (5, 3)
#
# Column Names:
# Index(['name', 'Markes', 'Subject'], dtype='str')
