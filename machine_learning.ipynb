# %% [markdown]
# ### machine learning lifecycle
#
# -->> Data gerhring(strong it into a Data frame)
# ||
#
# -->>Data exploring
#
# -->> Data cleaning
#
# -->> Exploratory Data analysis(panda,matpiloat,seaborn)
#
# -->> data preprocessing
#
# -->> mechine learning models
#
# -->> For reading the content from a tabuler data that is stored in a 2D structure or in rows and columns formet or consisting of multiple series in combination we requre Dataframe we can have the function to explore and to performe manipulation and anayliss on the Data we are going to store inside it.
